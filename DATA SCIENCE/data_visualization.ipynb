# %%
# !pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\danish\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
df = pd.read_csv('Cleaned_data.csv',index_col=0)

# %%
df.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df.to_csv('Cleaned_data.csv')

# %%
df['1980'].plot()
# Out:
# <AxesSubplot:>

# %%
df['2013'].plot()
# Out:
# <AxesSubplot:>

# %%
df.set_index('OdName',inplace=True)

# %%
df.loc['India']
# Out:
# Type                Immigrants
# Coverage            Foreigners
# AREA                       935
# AreaName                  Asia
# REG                       5501
# RegName          Southern Asia
# DEV                        902
# DevName     Developing regions
# 1980                      8880
# 1981                      8670
# 1982                      8147
# 1983                      7338
# 1984                      5704
# 1985                      4211
# 1986                      7150
# 1987                     10189
# 1988                     11522
# 1989                     10343
# 1990                     12041
# 1991                     13734
# 1992                     13673
# 1993                     21496
# 1994                     18620
# 1995                     18489
# 1996                     23859
# 1997                     22268
# 1998                     17241
# 1999                     18974
# 2000                     28572
# 2001                     31223
# ...

# %%
df
# Out:
#                       Type    Coverage  AREA AreaName   REG  \
# OdName
# Afghanistan     Immigrants  Foreigners   935     Asia  5501
# Albania         Immigrants  Foreigners   908   Europe   925
# Algeria         Immigrants  Foreigners   903   Africa   912
# American Samoa  Immigrants  Foreigners   909  Oceania   957
# Andorra         Immigrants  Foreigners   908   Europe   925
# ...                    ...         ...   ...      ...   ...
# Viet Nam        Immigrants  Foreigners   935     Asia   920
# Western Sahara  Immigrants  Foreigners   903   Africa   912
# Yemen           Immigrants  Foreigners   935     Asia   922
# Zambia          Immigrants  Foreigners   903   Africa   910
# Zimbabwe        Immigrants  Foreigners   903   Africa   910
#
#                            RegName  DEV             DevName  1980  1981  ...  \
# OdName                                                                   ...
# Afghanistan          Southern Asia  902  Developing regions    16    39  ...
# ...

# %%
years = [str(i)for i in range(1980, 2014)]

# %%
df.loc['India',years]
# Out:
# 1980     8880
# 1981     8670
# 1982     8147
# 1983     7338
# 1984     5704
# 1985     4211
# 1986     7150
# 1987    10189
# 1988    11522
# 1989    10343
# 1990    12041
# 1991    13734
# 1992    13673
# 1993    21496
# 1994    18620
# 1995    18489
# 1996    23859
# 1997    22268
# 1998    17241
# 1999    18974
# 2000    28572
# 2001    31223
# 2002    31889
# 2003    27155
# 2004    28235
# 2005    36210
# 2006    33848
# 2007    28742
# 2008    28261
# 2009    29456
# 2010    34235
# 2011    27509
# 2012    30933
# 2013    33087
# Name: India, dtype: object

# %%
df.loc['India',years].plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[['India', 'China'],years]
# Out:
#         1980  1981  1982  1983  1984  1985  1986   1987   1988   1989  ...  \
# OdName                                                                 ...
# India   8880  8670  8147  7338  5704  4211  7150  10189  11522  10343  ...
# China   5123  6682  3308  1863  1527  1816  1960   2643   2758   4323  ...
#
#          2004   2005   2006   2007   2008   2009   2010   2011   2012   2013
# OdName
# India   28235  36210  33848  28742  28261  29456  34235  27509  30933  33087
# China   36619  42584  33518  27642  30037  29622  30391  28502  33024  34129
#
# [2 rows x 34 columns]

# %%
df.loc[['India', 'China'],years].plot()
# Out:
# <AxesSubplot:xlabel='OdName'>

# %%
df.loc[['India', 'China'],years].T
# Out:
# OdName  India  China
# 1980     8880   5123
# 1981     8670   6682
# 1982     8147   3308
# 1983     7338   1863
# 1984     5704   1527
# 1985     4211   1816
# 1986     7150   1960
# 1987    10189   2643
# 1988    11522   2758
# 1989    10343   4323
# 1990    12041   8076
# 1991    13734  14255
# 1992    13673  10846
# 1993    21496   9817
# 1994    18620  13128
# 1995    18489  14398
# 1996    23859  19415
# 1997    22268  20475
# 1998    17241  21049
# 1999    18974  30069
# 2000    28572  35529
# 2001    31223  36434
# 2002    31889  31961
# 2003    27155  36439
# 2004    28235  36619
# 2005    36210  42584
# 2006    33848  33518
# 2007    28742  27642
# 2008    28261  30037
# 2009    29456  29622
# 2010    34235  30391
# 2011    27509  28502
# 2012    30933  33024
# 2013    33087  34129

# %%
df.loc[['India', 'China'],years].T.plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[['India', 'China','Philippines','Viet Nam'],years].T.plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
df.loc[['India', 'China','Philippines','Viet Nam'],years].T.plot(figsize=(20,7))
plt.title('Immigrations Time-Line of Some Asian Country',size=20)
plt.xlabel('Years',size=15)
plt.ylabel('Number of immigrations',size=15)
plt.xticks(size=18,rotation = 40)
plt.yticks(size=18, rotation = 40)
# Out:
# (array([-10000.,      0.,  10000.,  20000.,  30000.,  40000.,  50000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ## 1. Visulalize top 5 Countries of Europe.
# ## 2. Visulalize immigration of sum of all countries of Asia.

# %% [markdown]
# ## BAR CHARTS

# %%
df['1990']
# Out:
# OdName
# Afghanistan       1028
# Albania              3
# Algeria            491
# American Samoa       2
# Andorra              3
#                   ...
# Viet Nam          3801
# Western Sahara       0
# Yemen                4
# Zambia              77
# Zimbabwe           129
# Name: 1990, Length: 195, dtype: int64

# %%
top_5_Europe = df[df['AreaName']=='Europe'].sort_values('1990' , ascending=False)['2010'].head()

# %%
Northern_America = df[df['AreaName']=='Northern America'].sort_values('1990' , ascending=False)['2001']

# %%
Northern_America
# Out:
# OdName
# United States of America    5604
# Canada                         0
# Name: 2001, dtype: int64

# %%
Northern_America.plot(kind = 'line',figsize=(20,8))
plt.title('Immigrations Time-Line of Some Northern America Country',size=20)
plt.xlabel('Country Name',size=15)
plt.ylabel('Number of immigrations',size=15)
plt.xticks(size=18,rotation = 90)
plt.yticks(size=18, rotation = 40)
# Out:
# (array([-1000.,     0.,  1000.,  2000.,  3000.,  4000.,  5000.,  6000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
Northern_America.plot(kind = 'bar',figsize=(20,8))
plt.title('Immigrations Time-Line of Some Northern America Country',size=20)
plt.xlabel('Country Name',size=15)
plt.ylabel('Number of immigrations',size=15)
plt.xticks(size=18,rotation = 90)
plt.yticks(size=18, rotation = 40)
# Out:
# (array([   0., 1000., 2000., 3000., 4000., 5000., 6000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
Latin_America = df[df['AreaName']=='Latin America'].sort_values('1980' , ascending=False)['2013']

# %%
Latin_America
# Out:
# Series([], Name: 2013, dtype: int64)

# %%
Latin_America.plot(kind = 'line',figsize=(20,8))
plt.title('Immigrations Time-Line of Some Latin_America Country',size=20)
# Out:
# Text(0.5, 1.0, 'Immigrations Time-Line of Some Latin_America Country')

# %%
top_5_Europe.plot(kind = 'bar', figsize=(20,8))
plt.title('Immigrations Time-Line of Some Europe Country',size=20)
plt.xlabel('Country Name',size=15)
plt.ylabel('Number of immigrations',size=15)
plt.xticks(size=18,rotation = 90)
plt.yticks(size=18, rotation = 40)
# Out:
# (array([    0.,  2000.,  4000.,  6000.,  8000., 10000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
top_5_Europe.plot(kind = 'barh', figsize=(20,8))
plt.title('Immigrations Time-Line of Some Europe Country',size=20)
plt.xlabel('Country Name',size=15)
plt.ylabel('Number of immigrations',size=15)
# Out:
# Text(0, 0.5, 'Number of immigrations')

# %%
df['2013'].plot(kind = "hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.sum()
# Out:
# Type        ImmigrantsImmigrantsImmigrantsImmigrantsImmigr...
# Coverage    ForeignersForeignersForeignersForeignersForeig...
# AREA                                                   177989
# AreaName    AsiaEuropeAfricaOceaniaEuropeAfricaLatin Ameri...
# REG                                                    243558
# RegName     Southern AsiaSouthern EuropeNorthern AfricaPol...
# DEV                                                    175842
# DevName     Developing regionsDeveloped regionsDeveloping ...
# 1980                                                    99137
# 1981                                                   110563
# 1982                                                   104271
# 1983                                                    75550
# 1984                                                    73417
# 1985                                                    69978
# 1986                                                    86048
# ...

# %%
df['Total']=df.sum(axis=1)
# Out:
# C:\Users\danish\AppData\Local\Temp/ipykernel_17760/2407737632.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Total']=df.sum(axis=1)

# %%
df
# Out:
#                       Type    Coverage  AREA AreaName   REG  \
# OdName
# Afghanistan     Immigrants  Foreigners   935     Asia  5501
# Albania         Immigrants  Foreigners   908   Europe   925
# Algeria         Immigrants  Foreigners   903   Africa   912
# American Samoa  Immigrants  Foreigners   909  Oceania   957
# Andorra         Immigrants  Foreigners   908   Europe   925
# ...                    ...         ...   ...      ...   ...
# Viet Nam        Immigrants  Foreigners   935     Asia   920
# Western Sahara  Immigrants  Foreigners   903   Africa   912
# Yemen           Immigrants  Foreigners   935     Asia   922
# Zambia          Immigrants  Foreigners   903   Africa   910
# Zimbabwe        Immigrants  Foreigners   903   Africa   910
#
#                            RegName  DEV             DevName  1980  1981  ...  \
# OdName                                                                   ...
# Afghanistan          Southern Asia  902  Developing regions    16    39  ...
# ...

# %%
df.groupby('AreaName').sum()
# Out:
#                                   AREA     REG    DEV   1980   1981   1982  \
# AreaName
# Africa                           48762   49242  48708   3951   4363   3819
# Asia                             45815  109147  44197  31025  34314  30214
# Europe                           39044   39754  38743  39760  44802  42720
# Latin America and the Caribbean  29832   30395  29766  13081  15215  16769
# Northern America                  1810    1810   1802   9378  10030   9074
# Oceania                          12726   13210  12626   1942   1839   1675
#
#                                   1983   1984   1985   1986  ...    2005  \
# AreaName                                                     ...
# Africa                            2671   2639   2650   3782  ...   27523
# Asia                             24696  27274  23850  28739  ...  159253
# Europe                           24638  22287  20844  24370  ...   35955
# Latin America and the Caribbean  15427  13678  15171  21179  ...   24747
# ...

# %%
AreaName= df.groupby('AreaName').sum()['Total']

# %%
AreaName.plot(kind="pie",autopct="%1.2f%%", figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
explode = [0,0,0.2,0,0.3,0]
AreaName.plot(kind="pie",explode=explode, shadow=True, autopct="%1.2f%%", figsize=(20,10),labels= None)
plt.legend(AreaName.index, loc='upper left')

# %%
AreaName.plot(kind="pie",autopct="%1.2f%%", pctdistance=0.7, figsize=(20,10),labels= None, wedgeprops={ 'width': 0.5})
plt.legend(AreaName.index, loc='upper left')
