# %%
import pandas as pd

# %% [markdown]
# ## READ DATA

# %%
pd.read_csv("Pokemon.csv")                                   ## comma seprated value
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df = pd.read_csv("Pokemon.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.size
# Out:
# 10400

# %%
df.shape
# Out:
# (800, 13)

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.head(9)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# ...

# %% [markdown]
# # REmoving Columns

# %%
df.drop(columns=['#'])
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.drop(columns=['#'] , inplace = True)

# %%
df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.Name
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
name = df.Name

# %%
type(df.Name)
# Out:
# pandas.core.series.Series

# %%
df.Type1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11048/1147349363.py in <module>
# ----> 1 df.Type1
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Type1'

# %%
df['Type 1']
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
df[[ 'Name', 'Type 1', 'HP' ]]
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
df[[ 'Sp. Def', 'Speed' ]]
# Out:
#      Sp. Def  Speed
# 0         65     45
# 1         80     60
# 2        100     80
# 3        120     80
# 4         50     65
# ..       ...    ...
# 795      150     50
# 796      110    110
# 797      130     70
# 798      130     80
# 799       90     70
#
# [800 rows x 2 columns]

# %%
df.loc[10]
# Out:
# Name          Wartortle
# Type 1            Water
# Type 2              NaN
# Total               405
# HP                   59
# Attack               63
# Defense              80
# Sp. Atk              65
# Sp. Def              80
# Speed                58
# Generation            1
# Legendary         False
# Name: 10, dtype: object

# %%
df[40 :50]
# Out:
#           Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 40    Clefairy   Fairy     NaN    323   70      45       48       60       65
# 41    Clefable   Fairy     NaN    483   95      70       73       95       90
# 42      Vulpix    Fire     NaN    299   38      41       40       50       65
# 43   Ninetales    Fire     NaN    505   73      76       75       81      100
# 44  Jigglypuff  Normal   Fairy    270  115      45       20       45       25
# 45  Wigglytuff  Normal   Fairy    435  140      70       45       85       50
# 46       Zubat  Poison  Flying    245   40      45       35       30       40
# 47      Golbat  Poison  Flying    455   75      80       70       65       75
# 48      Oddish   Grass  Poison    320   45      50       55       75       65
# 49       Gloom   Grass  Poison    395   60      65       70       85       75
#
#     Speed  Generation  Legendary
# 40     35           1      False
# 41     60           1      False
# ...

# %%
df.loc[5:20]
# Out:
#                          Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 5                  Charmeleon    Fire     NaN    405  58      64       58
# 6                   Charizard    Fire  Flying    534  78      84       78
# 7   CharizardMega Charizard X    Fire  Dragon    634  78     130      111
# 8   CharizardMega Charizard Y    Fire  Flying    634  78     104       78
# 9                    Squirtle   Water     NaN    314  44      48       65
# 10                  Wartortle   Water     NaN    405  59      63       80
# 11                  Blastoise   Water     NaN    530  79      83      100
# 12    BlastoiseMega Blastoise   Water     NaN    630  79     103      120
# 13                   Caterpie     Bug     NaN    195  45      30       35
# 14                    Metapod     Bug     NaN    205  50      20       55
# 15                 Butterfree     Bug  Flying    395  60      45       50
# 16                     Weedle     Bug  Poison    195  40      35       30
# ...

# %%
df[['Name', 'Type 1']].loc[20:40]
# Out:
#                    Name    Type 1
# 20               Pidgey    Normal
# 21            Pidgeotto    Normal
# 22              Pidgeot    Normal
# 23  PidgeotMega Pidgeot    Normal
# 24              Rattata    Normal
# 25             Raticate    Normal
# 26              Spearow    Normal
# 27               Fearow    Normal
# 28                Ekans    Poison
# 29                Arbok    Poison
# 30              Pikachu  Electric
# 31               Raichu  Electric
# 32            Sandshrew    Ground
# 33            Sandslash    Ground
# 34             Nidoran♀    Poison
# 35             Nidorina    Poison
# 36            Nidoqueen    Poison
# 37             Nidoran♂    Poison
# 38             Nidorino    Poison
# 39             Nidoking    Poison
# 40             Clefairy     Fairy

# %%
# FIND THE NAME, Type 2 , attack, Defence From index 10 to 100

df[['Name', 'Type 2', 'Attack', 'Defense']].loc[10:100]
# Out:
#                         Name  Type 2  Attack  Defense
# 10                 Wartortle     NaN      63       80
# 11                 Blastoise     NaN      83      100
# 12   BlastoiseMega Blastoise     NaN     103      120
# 13                  Caterpie     NaN      30       35
# 14                   Metapod     NaN      20       55
# ..                       ...     ...     ...      ...
# 96                       Muk     NaN     105       75
# 97                  Shellder     NaN      65      100
# 98                  Cloyster     Ice      95      180
# 99                    Gastly  Poison      35       30
# 100                  Haunter  Poison      50       45
#
# [91 rows x 4 columns]

# %%
df[ 'Name' ] == 'Pikachu'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Name, Length: 800, dtype: bool

# %%
df[df[ 'Name' ] == 'Pikachu']
# Out:
#        Name    Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 30  Pikachu  Electric    NaN    320  35      55       40       50       50
#
#     Speed  Generation  Legendary
# 30     90           1      False

# %%
df[df[ 'Type 1' ] == 'Fire']
# Out:
#                           Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 4                   Charmander   Fire       NaN    309   39      52       43
# 5                   Charmeleon   Fire       NaN    405   58      64       58
# 6                    Charizard   Fire    Flying    534   78      84       78
# 7    CharizardMega Charizard X   Fire    Dragon    634   78     130      111
# 8    CharizardMega Charizard Y   Fire    Flying    634   78     104       78
# 42                      Vulpix   Fire       NaN    299   38      41       40
# 43                   Ninetales   Fire       NaN    505   73      76       75
# 63                   Growlithe   Fire       NaN    350   55      70       45
# 64                    Arcanine   Fire       NaN    555   90     110       80
# 83                      Ponyta   Fire       NaN    410   50      85       55
# 84                    Rapidash   Fire       NaN    500   65     100       70
# ...

# %%
df[df[ 'Attack' ] >100]
# Out:
#                           Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 7    CharizardMega Charizard X     Fire  Dragon    634   78     130      111
# 8    CharizardMega Charizard Y     Fire  Flying    634   78     104       78
# 12     BlastoiseMega Blastoise    Water     NaN    630   79     103      120
# 19       BeedrillMega Beedrill      Bug  Poison    495   65     150       40
# 39                    Nidoking   Poison  Ground    505   81     102       77
# ..                         ...      ...     ...    ...  ...     ...      ...
# 793                    Yveltal     Dark  Flying    680  126     131       95
# 796        DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797        HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798         HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799                  Volcanion     Fire   Water    600   80     110      120
#
# ...
