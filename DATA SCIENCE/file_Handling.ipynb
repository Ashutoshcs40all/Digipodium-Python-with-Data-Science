# %%
with open('app.py') as contents:
    code = contents.read()

# %%
contents.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5900/2521934165.py in <module>
# ----> 1 contents.read()
#
# ValueError: I/O operation on closed file.

# %%
code.count('import')
# Out:
# 4

# %%
code.count('st')
# Out:
# 12

# %%
file_contents = open('app.py')
print(file_contents.read())

file_contents.close()
# Out:
# import streamlit as st
# import pandas as pd
#
# sidebar = st.sidebar
# import plotly.graph_objs as go
# import plotly.express as px
#
# sidebar.title("Sidebar Title Here")
#
# btn1 = sidebar.button("Get Ballons")
#
# if btn1:
#     st.balloons()
#
# st.title("Pokemon Data")
#
# NAME =st.text_input("Enter Your Name")
# btn = st.button("Submit")
#
#
# if btn:
#      st.text(f"You entered name {NAME}")
#
#
# st.image("bit.jpg")
# df = pd.read_csv("Pokemon.csv")
# st.dataframe(df)
# fig= px.bar( data_frame= df, x=  'Name', y= 'Speed', color="Type 1" )
# st.plotly_chart(fig, use_container_width= True)
# fig1 = px.scatter_3d( data_frame=df, x = "Attack", y = "Defense", z = "HP", opacity=0.7, height=1000, template='plotly_dark', color= "Type 1" )
# st.plotly_chart(fig1)

# %%
with open('new.text', 'w') as newfile:
    newfile.write("new content")

# %%
with open('new.text', 'a') as newfile:
    newfile.write("\n some content ")

# %%
with open('app.py', 'r') as mycode:
    t = mycode.read()
    t+="\n# ----------Code Copied with python script----------"
    with open('app_copy.py', 'w') as copier:
        copier.write(t)

# %%
import os

# %% [markdown]
# find current working folder

# %%
os.getcwd()
# Out:
# 'h:\\Digipodium Python with Data Science\\DATA SCIENCE'

# %%
os.listdir()
# Out:
# ['app.py',
#  'app_copy.py',
#  'app_duplicate',
#  'bit.jpg',
#  'Canada.xlsx',
#  'Cleaned_data.csv',
#  'data loding.ipynb',
#  'data_cleaning.ipynb',
#  'data_visualization.ipynb',
#  'exception_handling.ipynb',
#  'file_Handling.ipynb',
#  'flipkart.ipynb',
#  'image_processing.ipynb',
#  'image_processing22.ipynb',
#  'imdbscarper.ipynb',
#  'lowest.jpg',
#  'lowest.png',
#  'movie_data.xlsx',
#  'new.text',
#  'plotly.ipynb',
#  'Pokemon.csv',
#  'webscraping.ipynb',
#  'your folder']

# %%
os.mkdir("your folder")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5900/324716492.py in <module>
# ----> 1 os.mkdir("your folder")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'your folder'

# %%
os.rename('app_copy.py', 'app_original.py')

# %%
os.rename('app_original.py', 'your folder/app_original.py')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5900/3337842934.py in <module>
# ----> 1 os.rename('app_original.py', 'your folder/app_original.py')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'app_original.py' -> 'your folder/app_original.py'

# %%
os.rename('array_processing.ipynb', 'your folder/array_processing.ipynb')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5900/2539312803.py in <module>
# ----> 1 os.rename('array_processing.ipynb', 'your folder/array_processing.ipynb')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'array_processing.ipynb' -> 'your folder/array_processing.ipynb'

# %%
with open('../dict.ipynb') as f:
    print(f.read())
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 1,
#    "source": [
#     "alpha = {'a' : 'apple' , 'b' : 'bat', 'c' : 'cat'}"
#    ],
#    "outputs": [],
#    "metadata": {}
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 2,
#    "source": [
#     "d1 = {}"
#    ],
#    "outputs": [],
#    "metadata": {}
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 3,
#    "source": [
#     "type(d1)"
#    ],
#    "outputs": [
#     {
#      "output_type": "execute_result",
#      "data": {
#       "text/plain": [
#        "dict"
#       ]
#      },
#      "metadata": {},
#      "execution_count": 3
#     }
#    ],
#    "metadata": {}
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "source": [
#     "set()\r\n",
#     "tuple()\r\n"
#    ],
#    "outputs": [],
#    "metadata": {}
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 4,
#    "source": [
# ...

# %%
with open('../classes.py') as f:
    print(f.read())
# Out:
# #class laptop:
#
#     ram = "8 gb"
#     brand = 'HP'
#     sdd = '1 TB'
#     resolution = '1280p'
#
#     def playGame(self):
#         print('Laptop plays games')
#
#     def playVideo(self):
#         print('laptop plays videos')
#
# lappy = laptop()
#
# lappy.playGame()
# lappy.playVideo
# print(lappy.resolution)

# %%
with open("C:/Users/danish/Desktop/new.text",'w') as newfile:
      newfile.write("new content")

# %%
import os

# %%
os.listdir()
# Out:
# ['app.py',
#  'app_duplicate',
#  'app_original.py',
#  'bit.jpg',
#  'Canada.xlsx',
#  'Cleaned_data.csv',
#  'data loding.ipynb',
#  'data_cleaning.ipynb',
#  'data_visualization.ipynb',
#  'exception_handling.ipynb',
#  'file_Handling.ipynb',
#  'flipkart.ipynb',
#  'image_processing.ipynb',
#  'image_processing22.ipynb',
#  'imdbscarper.ipynb',
#  'lowest.jpg',
#  'lowest.png',
#  'movie_data.xlsx',
#  'new.text',
#  'plotly.ipynb',
#  'Pokemon.csv',
#  'webscraping.ipynb',
#  'your folder']
